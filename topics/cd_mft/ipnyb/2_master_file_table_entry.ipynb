# %%
dd_image_path = "/home/etinoxa/Documents/image/cfreds_2015_data_leakage_pc.dd"
dd_image_offset = 206848

# %%
import pytsk3
from datetime import datetime, timezone, timedelta
import pytz
import argparse

# Usage: python3 USNJournaling_scripts/2_master_file_table_entry.py cfreds_2015_data_leakage_pc.dd 206848
def get_meta(image_path, offset):
    image = pytsk3.Img_Info(image_path)
    partition_offset = offset * 512
    fs = pytsk3.FS_Info(image, offset=partition_offset)

    def to_edt(utc, nano):
        utc_datetime = datetime.utcfromtimestamp(utc)
        edt_timezone = pytz.timezone('America/New_York')
        edt_datetime = utc_datetime.replace(tzinfo=timezone.utc).astimezone(edt_timezone)
        return edt_datetime.strftime(f"%Y-%m-%d %H:%M:%S.{nano} (%Z)")

    def list_inodes(fs, inode_number=None):
        for file in fs:
            if not file.info.meta or file.info.meta.type == pytsk3.TSK_FS_META_TYPE_DIR:
                continue  # Skip directories and non-files
            print_metadata(file)

    def print_metadata(file):
        print("\nFile Metadata:")
        print(f"Name: {file.info.name.name.decode()}")
        print(f"Size: {file.info.meta.size}")
        print(f"Entry: {file.info.meta.addr}")
        print(f"Link: {file.info.meta.nlink}")
        print(f"Sequence: {file.info.meta.seq}")
        print(f"Type: {file.info.meta.type}")
        print(f"Flags: {file.info.meta.flags}")
        print(f"File Modified: {to_edt(file.info.meta.mtime, file.info.meta.mtime_nano)}")
        print(f"Accessed: {to_edt(file.info.meta.atime, file.info.meta.atime_nano)}")
        print(f"MTF Modified: {to_edt(file.info.meta.ctime, file.info.meta.ctime_nano)}")
        print(f"Created: {to_edt(file.info.meta.crtime, file.info.meta.crtime_nano)}")

    # Start listing inodes from the root directory
    root_dir = pytsk3.Directory(fs, inode=fs.info.root_inum)
    list_inodes(root_dir)

if __name__ == "__main__":
    get_meta(dd_image_path, dd_image_offset)
# Out:
# File Metadata:
# Name: $AttrDef
# Size: 2560
# Entry: 4
# Link: 1
# Sequence: 4
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $BadClus
# Size: 0
# Entry: 8
# Link: 1
# Sequence: 8
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $Bitmap
# Size: 652096
# Entry: 6
# Link: 1
# Sequence: 6
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $Boot
# Size: 8192
# Entry: 7
# Link: 1
# Sequence: 7
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $LogFile
# Size: 67108864
# Entry: 2
# Link: 1
# Sequence: 2
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $MFT
# Size: 79953920
# Entry: 0
# Link: 1
# Sequence: 1
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $MFTMirr
# Size: 4096
# Entry: 1
# Link: 1
# Sequence: 1
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $Secure
# Size: 0
# Entry: 9
# Link: 1
# Sequence: 9
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $UpCase
# Size: 131072
# Entry: 10
# Link: 1
# Sequence: 10
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: $Volume
# Size: 0
# Entry: 3
# Link: 1
# Sequence: 3
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Accessed: 2015-03-25 07:08:36.956950100 (EDT)
# MTF Modified: 2015-03-25 07:08:36.956950100 (EDT)
# Created: 2015-03-25 07:08:36.956950100 (EDT)
#
# File Metadata:
# Name: hiberfil.sys
# Size: 1610211328
# Entry: 504
# Link: 1
# Sequence: 9
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 09:05:35.58022100 (EDT)
# Accessed: 2015-03-25 09:05:35.58022100 (EDT)
# MTF Modified: 2015-03-25 09:05:35.58022100 (EDT)
# Created: 2015-03-25 06:15:18.120039800 (EDT)
#
# File Metadata:
# Name: pagefile.sys
# Size: 2146951168
# Entry: 58995
# Link: 1
# Sequence: 2
# Type: 1
# Flags: 5
# File Modified: 2015-03-25 09:05:36.181224000 (EDT)
# Accessed: 2015-03-25 06:15:19.180841600 (EDT)
# MTF Modified: 2015-03-25 09:05:36.181224000 (EDT)
# Created: 2015-03-25 06:15:19.180841600 (EDT)
#
# File Metadata:
# Name: $OrphanFiles
# Size: 0
# Entry: 78080
# Link: 1
# Sequence: 0
# Type: 11
# Flags: 5
# File Modified: 1969-12-31 19:00:00.0 (EST)
# Accessed: 1969-12-31 19:00:00.0 (EST)
# MTF Modified: 1969-12-31 19:00:00.0 (EST)
# Created: 1969-12-31 19:00:00.0 (EST)
